# %% [markdown]
# <p style="font-family:Times New Roman; font-size:120%">
#     -Aleksander Nistad Sekkelsten
# </p>
# <h1 style="font-family:Times New Roman; font-size: 300%"><center> Machine Learning For Physics </center></h1>
#
#
# <h2 style="font-family:Times New Roman; font-weight:bolder; font-size:240%">Exercise week 35</h2>
#
# <p style="font-family:Times New Roman; font-size:120%">
#     The following notebook is my submition of the exercise of week 35
# </p>

# %% [markdown]
# <h2 style="font-family:Times New Roman; font-size:200%">Part I</h2>
# $$
# \text{part a) show that: } \frac{\partial \mathbf{a^Tx}}{\partial \mathbf x} = \mathbf a^T \\
# \text{for an element }\textit{k: } \frac{\partial \mathbf{a^Tx}}{\partial x_k} = \frac{\partial }{\partial x_k} \sum_{i=1}^{N} a_i \cdot x_i = \sum_{i=1}^{N} a_i \cdot  \frac{\partial x_i}{\partial x_k} = a_k \rightarrow  \frac{\partial \mathbf{a^Tx}}{\partial \mathbf x} = [a_1, a_2\ldots, a_N] = \mathbf a^T \blacksquare
# $$
#
# $$
# \text{part b) show that: } \frac{\partial (\mathbf{a^TAa})}{\partial \mathbf a} = \mathbf a^T \left (A+A^T \right) \\
# \text{for an element }\textit{k: } \frac{\partial (\mathbf{a^TAa})}{\partial a_k} = \frac{\partial }{\partial a_k} \sum_{i=1}^{N}\sum_{j=1}^{N} a_iA_{ij}a_j =  \sum_{i=1}^{N}\sum_{j=1}^{N} \left (\frac{\partial a_i}{\partial a_k} A_{ij}a_j + a_iA_{ij}\frac{\partial a_j}{\partial a_k}\right) = \sum_{j=1}^{N} A_{kj}a_j+\sum_{i=1}^{N} a_iA_{ik} = \sum_{i=1}^{N} a_i \left( A_{ik}+ A_{ki} \right) \rightarrow \frac{\partial (\mathbf{a^TAa})}{\partial \mathbf x} = \mathbf a^T \left (A+A^T \right) \blacksquare
# $$
#
# $$
# \text{part c) show that: } \frac{\partial (\mathbf{x-As})^T(\mathbf{x-As})}{\partial \mathbf s} = -2 \left (\mathbf{x-As} \right)^T\mathbf A \\
# \text{for an element }\textit{k: } \frac{\partial }{\partial s_k} \sum_{i=1}^{N} \left(x_i- \sum_{j=1}^{N}A_{ij}s_j\right)^2 = \sum_{i=1}^{N}-2x_i \sum_{j=1}^{N}A_{ij}\frac{\partial s_j}{\partial s_k} +2 \left( \sum_{j=1}^{N}A_{ij}\frac{\partial s_j}{\partial s_k} \right) \left(\sum_{j=1}^{N}A_{ij} s_j \right) = \sum_{i=1}^{N}-2x_i A_{ik} +2 A_{ik}\left(\sum_{j=1}^{N}A_{ij} s_j \right) = -2\sum_{i=1}^{N}\left(x_i - \sum_{j=1}^{N}A_{ij} s_j \right) A_{ik} \rightarrow \frac{\partial (\mathbf{x-As})^T(\mathbf{x-As})}{\partial \mathbf s} = -2 \left (\mathbf{x-As} \right)^T\mathbf A \blacksquare
# $$
#
# $$
# \text{part d) show that: } -2\frac{\partial  \left ((\mathbf{x-As} \right)^T\mathbf A)}{\partial \mathbf s} \propto A^TA \\
# \text{first of all}-2\frac{\partial\left((\mathbf{x-As}\right)^T\mathbf A)}{\partial \mathbf s}= -2\frac {\partial(\mathbf{x}^TA-\mathbf{(As)}^TA)}{\partial \mathbf s} = 2\frac{\partial(\mathbf{(As)}^TA)}{\partial \mathbf s} \\
# \text{for an element }\textit{ l, k: } = 2\frac{\partial(\mathbf{(As)}^TA)_l}{\partial s_k} =2\sum_{i=1}^{N}A_{il}\sum_{j=1}^{N} A_{ij}\frac{\partial s_j}{\partial s_k} = 2\sum_{i=1}^{N}A_{il} A_{ik} = 2\sum_{i=1}^{N}A_{il} A_{ki}^T \rightarrow -2\frac{\partial  \left ((\mathbf{x-As} \right)^T\mathbf A)}{\partial \mathbf s} = 2A^TA \blacksquare
# $$

# %% [markdown]
# ---
# <p style="font-family:Times New Roman; font-size:120%">
#     Here I asked ChatGPT to organize my LaTeX code, which I think it did nicely!
# </p>
#
# ### Part a) Show that:
# $$
# \frac{\partial \mathbf{a^Tx}}{\partial \mathbf x} = \mathbf a^T
# $$
#
# For an element \( k \):
# $$
# \frac{\partial \mathbf{a^Tx}}{\partial x_k} = \frac{\partial }{\partial x_k} \sum_{i=1}^{N} a_i \cdot x_i = \sum_{i=1}^{N} a_i \cdot \frac{\partial x_i}{\partial x_k} = a_k
# $$
#
# Thus,
# $$
# \frac{\partial \mathbf{a^Tx}}{\partial \mathbf x} = [a_1, a_2, \ldots, a_N] = \mathbf a^T \blacksquare
# $$
#
# ### Part b) Show that:
# $$
# \frac{\partial (\mathbf{a^TAa})}{\partial \mathbf a} = \mathbf a^T \left( A + A^T \right)
# $$
#
# For an element \( k \):
# $$
# \frac{\partial (\mathbf{a^TAa})}{\partial a_k} = \frac{\partial }{\partial a_k} \sum_{i=1}^{N} \sum_{j=1}^{N} a_i A_{ij} a_j
# $$
#
# $$
# = \sum_{i=1}^{N} \sum_{j=1}^{N} \left( \frac{\partial a_i}{\partial a_k} A_{ij} a_j + a_i A_{ij} \frac{\partial a_j}{\partial a_k} \right)
# = \sum_{j=1}^{N} A_{kj} a_j + \sum_{i=1}^{N} a_i A_{ik}
# $$
#
# $$
# = \sum_{i=1}^{N} a_i \left( A_{ik} + A_{ki} \right)
# $$
#
# Thus,
# $$
# \frac{\partial (\mathbf{a^TAa})}{\partial \mathbf x} = \mathbf a^T \left( A + A^T \right) \blacksquare
# $$
#
# ### Part c) Show that:
# $$
# \frac{\partial (\mathbf{x-As})^T(\mathbf{x-As})}{\partial \mathbf s} = -2 \left(\mathbf{x-As} \right)^T \mathbf A
# $$
#
# For an element \( k \):
# $$
# \frac{\partial }{\partial s_k} \sum_{i=1}^{N} \left( x_i - \sum_{j=1}^{N} A_{ij} s_j \right)^2
# $$
#
# $$
# = \sum_{i=1}^{N} \left( -2x_i \sum_{j=1}^{N} A_{ij} \frac{\partial s_j}{\partial s_k} + 2 \left( \sum_{j=1}^{N} A_{ij} \frac{\partial s_j}{\partial s_k} \right) \left( \sum_{j=1}^{N} A_{ij} s_j \right) \right)
# $$
#
# $$
# = \sum_{i=1}^{N} \left( -2x_i A_{ik} + 2 A_{ik} \left( \sum_{j=1}^{N} A_{ij} s_j \right) \right)
# $$
#
# $$
# = -2 \sum_{i=1}^{N} \left( x_i - \sum_{j=1}^{N} A_{ij} s_j \right) A_{ik}
# $$
#
# Thus,
# $$
# \frac{\partial (\mathbf{x-As})^T(\mathbf{x-As})}{\partial \mathbf s} = -2 \left( \mathbf{x-As} \right)^T \mathbf A \blacksquare
# $$
#
# ### Part d) Show that:
# $$
# -2\frac{\partial \left( (\mathbf{x-As})^T \mathbf A \right)}{\partial \mathbf s} \propto A^T A
# $$
#
# First of all,
# $$
# -2\frac{\partial \left( (\mathbf{x-As})^T \mathbf A \right)}{\partial \mathbf s} = -2\frac{\partial \left( \mathbf{x}^T \mathbf A - \mathbf{(As)}^T \mathbf A \right)}{\partial \mathbf s} = 2 \frac{\partial \left( \mathbf{(As)}^T \mathbf A \right)}{\partial \mathbf s}
# $$
#
# For an element \( l, k \):
# $$
# 2\frac{\partial \left( \mathbf{(As)}^T \mathbf A \right)_l}{\partial s_k} = 2\sum_{i=1}^{N} A_{il} \sum_{j=1}^{N} A_{ij} \frac{\partial s_j}{\partial s_k} = 2\sum_{i=1}^{N} A_{il} A_{ik} = 2\sum_{i=1}^{N} A_{il} A_{ki}^T
# $$
#
# Thus,
# $$
# -2\frac{\partial \left( (\mathbf{x-As})^T \mathbf A \right)}{\partial \mathbf s} = 2A^T A \blacksquare
# $$

# %% [markdown]
# <h2 style="font-family:Times New Roman; font-size:200%">Part II & III</h2>

# %%
import Pkg; Pkg.activate(".julia/environments/v1.10/Project.toml")
using Flux, Plots, Random, NBInclude, LinearAlgebra
using StatsBase: sample
Pkg.add("PlotThemes")
theme(:ggplot2)
# Out:
#   Activating project at `~/.julia/environments/v1.10`
#    Resolving package versions...
#   No Changes to `~/.julia/environments/v1.10/Project.toml`
#   No Changes to `~/.julia/environments/v1.10/Manifest.toml`

# %% [markdown]
# <h2 style="font-family:Times New Roman; font-size:200%">Generating polynomial data</h2>

# %%
n=100
f(x) = 2x^2-3*x-2
#x_data = randn(n) #Normally distributed x-data, this could of course be linear as well, it doesn't really matter
x_data = LinRange(-3,3, 100) |> collect # Linear
y_data = f.(x_data).+ 0.1.*randn(n)
# Out:
# 100-element Vector{Float64}:
#  24.84862513592238
#  24.0804785731571
#  22.96212603372669
#  22.340131279217974
#  21.63833201264302
#  20.601156019089153
#  19.749263504983627
#  19.034376749220833
#  18.183039259282182
#  17.494919997430316
#  16.576602434428896
#  15.865666271356478
#  15.03699885268793
#   ⋮
#   1.932041803704606
#   2.2217992592746203
#   2.6825477318772943
#   3.1029655615565086
#   3.4869988594292387
#   3.870242744606488
#   4.293303767979196
#   4.887449220226503
#   5.515979635350946
#   6.03342380078481
#   6.65283737838103
#   7.003078189415338

# %%
scatter(x_data,y_data, title="Polynomial Data", label="Data",fontfamily="Times New Roman")

# %% [markdown]
# <h2 style="font-family:Times New Roman; font-size:200%">Splitting the data into test/train</h2>

# %%
function SplitData(xData::Array, yData::Array, train_size::Float64)
    #Assumes Data : n_features, n_observations
    
    if ndims(xData)==1
        N = length(xData)
        NumTrain = Int(round(N*train_size))
            
        train_indices = sample(1:N, NumTrain; replace=false)
        all_indices = collect(1:N)
        test_indices = [i for i in all_indices if i ∉ train_indices]
        
        xTrain = xData[train_indices]
        yTrain = yData[train_indices]
        xTest = xData[test_indices]
        yTest = yData[test_indices]
        
    elseif ndims(xData)==2 #If there are for multiple features for each datapoint i.e position, velocity
        N = length(xData[1,:])
        NumTrain = Int(round(N*train_size))
            
        train_indices = sample(1:N, NumTrain; replace=false)
        all_indices = collect(1:N)
        test_indices = [i for i in all_indices if i ∉ train_indices]
        
        xTrain = xData[:,train_indices]
        yTrain = yData[:,train_indices]
        xTest = xData[:,test_indices]
        yTest = yData[:,test_indices]
    else #This is undefined
        @warn "Array dimensions do not match the expected dimensions." 
        println("Expected: 1 or 2, but got: ", ndims(xData))
        return
    end
    return xTrain, xTest, yTrain, yTest
end
# Out:
# SplitData (generic function with 1 method)

# %%
xtrain, xtest, ytrain, ytest = SplitData(x_data, y_data, 0.8)
# Out:
# ([-0.3939393939393936, -2.878787878787879, -0.2727272727272727, -1.9090909090909087, 3.0, 0.9393939393939394, 0.3333333333333335, 1.121212121212121, 1.4242424242424239, 2.878787878787879  …  -0.5757575757575759, 2.1515151515151514, -2.454545454545454, -1.4242424242424239, 2.3939393939393945, 2.6363636363636367, 2.333333333333333, -1.0, 1.8484848484848486, 0.09090909090909083], [-2.8181818181818183, -2.757575757575758, -2.575757575757576, -2.333333333333333, -2.2727272727272725, -2.2121212121212124, -1.727272727272727, -1.4848484848484846, -1.3636363636363635, -0.8787878787878787, -0.8181818181818183, -0.09090909090909083, 0.45454545454545503, 0.6363636363636367, 0.8181818181818183, 1.0, 1.3030303030303028, 1.6060606060606055, 2.454545454545454, 2.8181818181818183], [-0.5693617890052607, 23.28397665631368, -1.0789984956945513, 11.033270913328021, 7.141878456387758, -3.140406877198646, -2.9455580986877137, -2.837839378710297, -2.0657519956287986, 5.894683737294232  …  0.214940519626915
# ...

# %%
scatter(xtrain, ytrain, label= "Train", title="Tran/Test split for polynomial")
scatter!(xtest, ytest, label="Test")

# %%
function Regression(xData, yData, numDegrees::Int64)
    DesignMatrix = zeros(length(xData), numDegrees+1)
    for i in 1:numDegrees+1
        DesignMatrix[:,i].=xData.^(i-1)
    end
    Hessian = Transpose(DesignMatrix)*DesignMatrix
    beta = inv(Hessian)*Transpose(DesignMatrix)*yData
    return beta
end

function MSE(y,x, beta)
    N = length(x)
    DesignMatrix = zeros(length(x), length(beta)) 
    for i in 1:length(beta)
        DesignMatrix[:,i].=x.^(i-1)
    end
    MSE = 1/N*sum((y .- DesignMatrix*beta).^2)
    return MSE
end

function R2(y,x, beta)
    N = length(x)
    DesignMatrix = zeros(length(x), length(beta)) 
    for i in 1:length(beta)
        DesignMatrix[:,i].=x.^(i-1)
    end
    y_avg = 1/N*sum(y)
    R2 = 1- sum((y.-DesignMatrix*beta).^2)/sum((y .- y_avg).^2)
    return R2
end
# Out:
# R2 (generic function with 1 method)

# %%
betaVals = Regression(xtrain,ytrain, 2)
beta0, beta1, beta2 = betaVals
model(x) = beta0 + beta1*x + beta2*x^2
# Out:
# model (generic function with 1 method)

# %%
y_hat=model.(xtest)
println("MSE: ", MSE(ytest,xtest,betaVals))
println("R2 value: ", R2(ytest,xtest,betaVals))
# Out:
# MSE: 0.010362357890066088
# R2 value: 0.9998609736837818

# %%
scatter(x_data, y_data, label = "ground truth", title="Result from the model")
scatter!(xtest,y_hat, label = "predicted data")

# %% [markdown]
# <h2 style="font-family:Times New Roman; font-size:200%">Non polynomial data</h2>

# %%
n=300
f_NotPoly(x) = 2*ℯ^x-5*cos(3*x-2)+3*x+2
#x_data = randn(n) #Normally distributed x-data, this could of course be linear as well, it doesn't really matter
x_data = LinRange(-3,3, n) |> collect # Linear
y_data = f_NotPoly.(x_data).+ 0.1.*randn(n)
scatter(x_data,y_data, label="Data", title="Random non polynomial funciton")

# %%
xtrain, xtest, ytrain, ytest = SplitData(x_data, y_data, 0.8)
# Out:
# ([2.638795986622074, -1.254180602006689, 0.8528428093645486, -2.1571906354515047, -0.0501672240802673, 2.7391304347826093, 2.8193979933110374, -2.839464882943144, -1.1538461538461535, 2.0367892976588626  …  0.43143812709030094, 1.9565217391304346, 0.5117056856187294, 1.8361204013377925, -2.0367892976588626, 2.719063545150502, 2.959866220735786, 1.6153846153846159, 2.217391304347826, -2.1973244147157187], [-2.8595317725752505, -2.638795986622074, -2.6187290969899664, -2.59866220735786, -2.578595317725753, -2.4581939799331103, -2.25752508361204, -2.177257525083612, -2.0769230769230766, -1.9966555183946486  …  2.25752508361204, 2.2775919732441468, 2.3177257525083608, 2.397993311036789, 2.438127090301003, 2.478260869565217, 2.4983277591973243, 2.558528428093646, 2.6989966555183944, 2.839464882943144], [33.21816813130517, -5.574188545227556, 4.8685044784266704, -1.435936749663079, 6.6187633579673, 36.00313280057518, 39.06706981382331, -4.160262262196218, -4.3570352969251855, 26.2875901632
# ...

# %%
function RandomPolyDegModel(xData, betas)
    #This function will calculate ỹ = ∑ β_i x^i for any number of degrees 
    N = length(xData)
    DesignMatrix = zeros(length(xData), length(betas)) 
    for i in 1:length(betas)
        DesignMatrix[:,i].=xData.^(i-1)
    end
    est = DesignMatrix*betas
    return est
end
# Out:
# RandomPolyDegModel (generic function with 1 method)

# %%
betaVals = Regression(xtrain,ytrain, 1)
y_hat=RandomPolyDegModel(xtest, betaVals)

mse = round(MSE(ytest,xtest,betaVals),digits=2)
r2 = round(R2(ytest,xtest,betaVals),digits=2)

p = plot(x_data, y_data, label = "Ground truth",alpha=0.7,layout=8, size = (900,900),linewidth=3)
scatter!(subplot=1, xtest, y_hat, label = "Degree=2, MSE: $(mse), R2: $(r2)")

degrees = range(2,8) |> collect
for deg in degrees
    betaVals = Regression(xtrain,ytrain, deg)

    y_hat=RandomPolyDegModel(xtest, betaVals)
    
    mse = round(MSE(ytest,xtest,betaVals),digits=2)
    r2 = round(R2(ytest,xtest,betaVals),digits=2)
    
    plot!(subplot=deg, x_data, y_data, label = "Ground truth", alpha=0.7, size = (900,900),linewidth=3)
    scatter!(subplot=deg, xtest,y_hat, label = "Degree=$(deg), MSE: $(mse), R2: $(r2)")
end
display(p)

# %% [markdown]
# <p style="font-family:Times New Roman; font-size:120%">
#     For this particular example, the MSE stays relatively constant until the polynomial reaches a degree of 7 and 8, where the MSE drastically decreases. I increased the number of datapoints for better visualization, the result is pretty similar with n=100 points. In this notebook, I also did not make the designmatrix inside the test/train split, that is because I didn't want to split the data several times for multiple polynomial degrees, so this solution was simpler.
# </p>

# %%
?MSE
# Out:
# search: MSE mse OptimiserChain MersenneTwister ComposedFunction
#   No documentation found.
#
#   MSE is a Function.
#
#   # 1 method for generic function "MSE":
#   [1] MSE(y, x, beta) in Main at In[44]:11

# %%
n=100
f_NotPoly(x) = 2*ℯ^x-5*cos(3*x-2)+3*x+2
#x_data = randn(n) #Normally distributed x-data, this could of course be linear as well, it doesn't really matter
x_data = LinRange(-3,3, n) |> collect # Linear
y_data = f_NotPoly.(x_data).+ 0.1.*randn(n)
scatter(x_data,y_data, label="Data", title="Random non polynomial funciton")
xtrain, xtest, ytrain, ytest = SplitData(x_data, y_data, 0.8)
# Out:
# ([2.6969696969696972, 2.454545454545454, 0.09090909090909083, -1.787878787878788, 2.333333333333333, -0.9393939393939394, -1.2424242424242422, -0.7575757575757576, -0.5757575757575759, 0.6969696969696968  …  -2.8181818181818183, -2.575757575757576, 1.1818181818181819, 2.212121212121213, 1.9090909090909092, -2.757575757575758, -2.6363636363636367, 0.15151515151515182, -0.030303030303030054, 2.2727272727272725], [-2.9393939393939394, -2.878787878787879, -2.454545454545454, -2.393939393939394, -2.333333333333333, -2.2727272727272725, -1.303030303030303, -1.1818181818181817, -1.121212121212121, -1.0606060606060606, -0.8787878787878787, -0.45454545454545436, -0.2727272727272727, -0.1515151515151516, 1.2424242424242422, 1.8484848484848486, 2.090909090909091, 2.6363636363636367, 2.8181818181818183, 3.0], [34.82684153567053, 29.605889147026154, 5.10445512236976, -5.543443946178722, 28.111816557908746, -0.568132940545625, -5.392010015024893, 2.8462252277002733, 5.656818308645943, 3.1198411478
# ...

# %%
degrees = range(1,30) |>collect
MSE_list = zeros(30)
for deg in 1:30
    betaVals = Regression(xtrain,ytrain, deg)
    y_hat=RandomPolyDegModel(xtest, betaVals)
    MSE_list[deg] = MSE(ytest,xtest,betaVals)

end

# %%
plot(degrees,MSE_list)
